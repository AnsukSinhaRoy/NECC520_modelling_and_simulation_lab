# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples
N = 30

# True parameter (unknown, to be estimated)
a_true = 10.0  

# Initial estimate and variance
a_est = 0  

P = 1  # Initial variance (high uncertainty)

# Storage for plotting
estimates = [a_est]
gains = []
variances = [P]
samples = []

# Simulation loop
for n in range(1, N+1):
    w_n = np.random.randn()
    x_n = a_true + w_n  

    # Update Estimate
    a_est = estimates[-1] + K * (x_n - estimates[-1])

    # Update Gain 
    K = P / (P + 1)

    # Update Variance
    P = (1 - K) * P

    print(f"Sample {n}: X_n = {x_n:.2f}, A_Hat = {a_est:.2f}, Gain = {K:.2f}, Variance = {P:.2f}")
    # Store values for plotting
    estimates.append(a_est)
    gains.append(K)
    variances.append(P)
    samples.append(n)

# Plot Gain over Samples
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(samples, gains, label="Gain (K)")
plt.xlabel("Sample Index")
plt.ylabel("Gain Value")
plt.title("Gain vs. Samples")
plt.legend()
plt.grid()

# Plot Variance over Samples
plt.subplot(1, 3, 2)
plt.plot(samples, variances[:-1], label="Variance (P)", color='r')
plt.xlabel("Sample Index")
plt.ylabel("Variance")
plt.title("Variance vs. Samples")
plt.legend()
plt.grid()

# Plot Estimate vs. True Value
plt.subplot(1, 3, 3)
plt.plot(samples, estimates[1:], label="Estimated a", color='g')
plt.axhline(y=a_true, color='k', linestyle="--", label="True a")
plt.xlabel("Sample Index")
plt.ylabel("Estimate")
plt.title("Estimate vs. Samples")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Sample 1: X_n = 10.19, A_Hat = 0.10, Gain = 0.50, Variance = 0.50
# Sample 2: X_n = 10.74, A_Hat = 5.42, Gain = 0.33, Variance = 0.33
# Sample 3: X_n = 8.73, A_Hat = 6.52, Gain = 0.25, Variance = 0.25
# Sample 4: X_n = 9.57, A_Hat = 7.28, Gain = 0.20, Variance = 0.20
# Sample 5: X_n = 9.71, A_Hat = 7.77, Gain = 0.17, Variance = 0.17
# Sample 6: X_n = 8.74, A_Hat = 7.93, Gain = 0.14, Variance = 0.14
# Sample 7: X_n = 10.00, A_Hat = 8.23, Gain = 0.12, Variance = 0.12
# Sample 8: X_n = 10.42, A_Hat = 8.50, Gain = 0.11, Variance = 0.11
# Sample 9: X_n = 9.80, A_Hat = 8.65, Gain = 0.10, Variance = 0.10
# Sample 10: X_n = 10.46, A_Hat = 8.83, Gain = 0.09, Variance = 0.09
# Sample 11: X_n = 10.86, A_Hat = 9.01, Gain = 0.08, Variance = 0.08
# Sample 12: X_n = 10.35, A_Hat = 9.12, Gain = 0.08, Variance = 0.08
# Sample 13: X_n = 10.47, A_Hat = 9.23, Gain = 0.07, Variance = 0.07
# Sample 14: X_n = 9.88, A_Hat = 9.27, Gain = 0.07, Variance = 0.07
# Sample 15: X_n = 9.27, A_Hat = 9.27, Gain = 0.06, Variance = 0.06
# Sample 16: X_n = 9.73, A_Hat = 9.30, Gain = 0.06, Variance = 0.06
# Sample 17: X_n = 9.18, A_Hat = 9.29, Gain = 0.06, Variance = 0.06
# Sample 18: X_n = 9.24, A_Hat = 9.29, Gain = 0.05, Variance = 0.05
# Sample 19: X_n = 9.57, A_Hat = 9.30, Gain = 0.05, Variance = 0.05
# Sample 20: X_n = 8.16, A_Hat = 9.25, Gain = 0.05, Variance = 0.05
# Sample 21: X_n = 8.59, A_Hat = 9.22, Gain = 0.05, Variance = 0.05
# Sample 22: X_n = 10.16, A_Hat = 9.26, Gain = 0.04, Variance = 0.04
# Sample 23: X_n = 11.55, A_Hat = 9.36, Gain = 0.04, Variance = 0.04
# Sample 24: X_n = 10.71, A_Hat = 9.41, Gain = 0.04, Variance = 0.04
# Sample 25: X_n = 9.27, A_Hat = 9.41, Gain = 0.04, Variance = 0.04
# Sample 26: X_n = 9.43, A_Hat = 9.41, Gain = 0.04, Variance = 0.04
# Sample 27: X_n = 10.41, A_Hat = 9.45, Gain = 0.04, Variance = 0.04
# Sample 28: X_n = 8.63, A_Hat = 9.42, Gain = 0.03, Variance = 0.03
# Sample 29: X_n = 10.48, A_Hat = 9.45, Gain = 0.03, Variance = 0.03
# Sample 30: X_n = 10.57, A_Hat = 9.49, Gain = 0.03, Variance = 0.03

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples
N = 100 

a_true = 10.0  

a_est = 0  
P = 1 

initial_samples = 4  

estimates = []
gains = []
variances = []
samples = []

x_values = []
for i in range(initial_samples):
    w_n = np.random.randn()  # Noise
    x_n = a_true + w_n  # Measurement
    x_values.append(x_n)

a_est = np.mean(x_values)
P = np.var(x_values, ddof=1)

estimates.append(a_est)
variances.append(P)

print(f"Initial Non-Sequential Estimate: {a_est:.2f}, Variance: {P:.2f}")

# Sequential Update Loop
for n in range(initial_samples + 1, N + 1):
    w_n = np.random.randn()
    x_n = a_true + w_n  

    # Compute Gain
    K = P / (P + 1)

    # Update Estimate
    a_est = a_est + K * (x_n - a_est)

    # Update Variance
    P = (1 - K) * P

    print(f"Sample {n}: X_n = {x_n:.2f}, A_Hat = {a_est:.2f}, Gain = {K:.2f}, Variance = {P:.2f}")

    # Store values for plotting
    estimates.append(a_est)
    gains.append(K)
    variances.append(P)
    samples.append(n)

# Plot Gain over Samples
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(samples, gains, label="Gain (K)")
plt.xlabel("Sample Index")
plt.ylabel("Gain Value")
plt.title("Gain vs. Samples")
plt.legend()
plt.grid()

# Plot Variance over Samples
plt.subplot(1, 3, 2)
plt.plot(samples, variances[1:], label="Variance (P)", color='r')
plt.xlabel("Sample Index")
plt.ylabel("Variance")
plt.title("Variance vs. Samples")
plt.legend()
plt.grid()

# Plot Estimate vs. True Value
plt.subplot(1, 3, 3)
plt.plot(samples, estimates[1:], label="Estimated a", color='g')
plt.axhline(y=a_true, color='k', linestyle="--", label="True a")
plt.xlabel("Sample Index")
plt.ylabel("Estimate")
plt.title("Estimate vs. Samples")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Initial Non-Sequential Estimate: 9.84, Variance: 0.38
# Sample 5: X_n = 10.57, A_Hat = 10.04, Gain = 0.28, Variance = 0.28
# Sample 6: X_n = 8.75, A_Hat = 9.76, Gain = 0.22, Variance = 0.22
# Sample 7: X_n = 10.71, A_Hat = 9.93, Gain = 0.18, Variance = 0.18
# Sample 8: X_n = 9.58, A_Hat = 9.88, Gain = 0.15, Variance = 0.15
# Sample 9: X_n = 8.55, A_Hat = 9.70, Gain = 0.13, Variance = 0.13
# Sample 10: X_n = 11.69, A_Hat = 9.93, Gain = 0.12, Variance = 0.12
# Sample 11: X_n = 7.68, A_Hat = 9.70, Gain = 0.10, Variance = 0.10
# Sample 12: X_n = 10.78, A_Hat = 9.80, Gain = 0.09, Variance = 0.09
# Sample 13: X_n = 9.12, A_Hat = 9.74, Gain = 0.09, Variance = 0.09
# Sample 14: X_n = 11.32, A_Hat = 9.87, Gain = 0.08, Variance = 0.08
# Sample 15: X_n = 10.34, A_Hat = 9.90, Gain = 0.07, Variance = 0.07
# Sample 16: X_n = 9.84, A_Hat = 9.90, Gain = 0.07, Variance = 0.07
# Sample 17: X_n = 9.98, A_Hat = 9.90, Gain = 0.06, Variance = 0.06
# Sample 18: X_n = 9.39, A_Hat = 9.87, Gain = 0.06, Variance = 0.06
# Sample 19: X_n = 7.88, A_Hat = 9.76, Gain = 0.06, Variance = 0.06
# Sample 20: X_n = 9.44, A_Hat = 9.74, Gain = 0.05, Variance = 0.05
# Sample 21: X_n = 9.91, A_Hat = 9.75, Gain = 0.05, Variance = 0.05
# Sample 22: X_n = 10.72, A_Hat = 9.80, Gain = 0.05, Variance = 0.05
# Sample 23: X_n = 8.35, A_Hat = 9.73, Gain = 0.05, Variance = 0.05
# Sample 24: X_n = 9.16, A_Hat = 9.70, Gain = 0.04, Variance = 0.04
# Sample 25: X_n = 10.41, A_Hat = 9.73, Gain = 0.04, Variance = 0.04
# Sample 26: X_n = 9.08, A_Hat = 9.71, Gain = 0.04, Variance = 0.04
# Sample 27: X_n = 12.16, A_Hat = 9.80, Gain = 0.04, Variance = 0.04
# Sample 28: X_n = 8.19, A_Hat = 9.74, Gain = 0.04, Variance = 0.04
# Sample 29: X_n = 9.32, A_Hat = 9.73, Gain = 0.04, Variance = 0.04
# Sample 30: X_n = 10.58, A_Hat = 9.76, Gain = 0.03, Variance = 0.03
# Sample 31: X_n = 9.30, A_Hat = 9.74, Gain = 0.03, Variance = 0.03
# Sample 32: X_n = 11.05, A_Hat = 9.79, Gain = 0.03, Variance = 0.03
# Sample 33: X_n = 11.30, A_Hat = 9.83, Gain = 0.03, Variance = 0.03
# Sample 34: X_n = 11.45, A_Hat = 9.88, Gain = 0.03, Variance = 0.03
# Sample 35: X_n = 8.50, A_Hat = 9.84, Gain = 0.03, Variance = 0.03
# Sample 36: X_n = 9.72, A_Hat = 9.84, Gain = 0.03, Variance = 0.03
# Sample 37: X_n = 10.53, A_Hat = 9.86, Gain = 0.03, Variance = 0.03
# Sample 38: X_n = 9.92, A_Hat = 9.86, Gain = 0.03, Variance = 0.03
# Sample 39: X_n = 8.60, A_Hat = 9.83, Gain = 0.03, Variance = 0.03
# Sample 40: X_n = 9.34, A_Hat = 9.81, Gain = 0.03, Variance = 0.03
# Sample 41: X_n = 9.57, A_Hat = 9.81, Gain = 0.03, Variance = 0.03
# Sample 42: X_n = 9.10, A_Hat = 9.79, Gain = 0.02, Variance = 0.02
# Sample 43: X_n = 9.28, A_Hat = 9.78, Gain = 0.02, Variance = 0.02
# Sample 44: X_n = 11.02, A_Hat = 9.81, Gain = 0.02, Variance = 0.02
# Sample 45: X_n = 10.78, A_Hat = 9.83, Gain = 0.02, Variance = 0.02
# Sample 46: X_n = 8.61, A_Hat = 9.80, Gain = 0.02, Variance = 0.02
# Sample 47: X_n = 11.09, A_Hat = 9.83, Gain = 0.02, Variance = 0.02
# Sample 48: X_n = 9.96, A_Hat = 9.83, Gain = 0.02, Variance = 0.02
# Sample 49: X_n = 10.30, A_Hat = 9.84, Gain = 0.02, Variance = 0.02
# Sample 50: X_n = 7.88, A_Hat = 9.80, Gain = 0.02, Variance = 0.02
# Sample 51: X_n = 10.18, A_Hat = 9.81, Gain = 0.02, Variance = 0.02
# Sample 52: X_n = 10.81, A_Hat = 9.83, Gain = 0.02, Variance = 0.02
# Sample 53: X_n = 10.57, A_Hat = 9.84, Gain = 0.02, Variance = 0.02
# Sample 54: X_n = 9.65, A_Hat = 9.84, Gain = 0.02, Variance = 0.02
# Sample 55: X_n = 11.20, A_Hat = 9.87, Gain = 0.02, Variance = 0.02
# Sample 56: X_n = 9.31, A_Hat = 9.86, Gain = 0.02, Variance = 0.02
# Sample 57: X_n = 8.26, A_Hat = 9.83, Gain = 0.02, Variance = 0.02
# Sample 58: X_n = 9.48, A_Hat = 9.82, Gain = 0.02, Variance = 0.02
# Sample 59: X_n = 9.65, A_Hat = 9.82, Gain = 0.02, Variance = 0.02
# Sample 60: X_n = 11.80, A_Hat = 9.85, Gain = 0.02, Variance = 0.02
# Sample 61: X_n = 11.03, A_Hat = 9.87, Gain = 0.02, Variance = 0.02
# Sample 62: X_n = 12.39, A_Hat = 9.91, Gain = 0.02, Variance = 0.02
# Sample 63: X_n = 11.07, A_Hat = 9.93, Gain = 0.02, Variance = 0.02
# Sample 64: X_n = 10.85, A_Hat = 9.95, Gain = 0.02, Variance = 0.02
# Sample 65: X_n = 8.53, A_Hat = 9.92, Gain = 0.02, Variance = 0.02
# Sample 66: X_n = 10.86, A_Hat = 9.94, Gain = 0.02, Variance = 0.02
# Sample 67: X_n = 9.34, A_Hat = 9.93, Gain = 0.02, Variance = 0.02
# Sample 68: X_n = 9.40, A_Hat = 9.92, Gain = 0.02, Variance = 0.02
# Sample 69: X_n = 7.91, A_Hat = 9.89, Gain = 0.01, Variance = 0.01
# Sample 70: X_n = 11.11, A_Hat = 9.91, Gain = 0.01, Variance = 0.01
# Sample 71: X_n = 9.82, A_Hat = 9.91, Gain = 0.01, Variance = 0.01
# Sample 72: X_n = 9.32, A_Hat = 9.90, Gain = 0.01, Variance = 0.01
# Sample 73: X_n = 10.07, A_Hat = 9.90, Gain = 0.01, Variance = 0.01
# Sample 74: X_n = 10.50, A_Hat = 9.91, Gain = 0.01, Variance = 0.01
# Sample 75: X_n = 9.79, A_Hat = 9.91, Gain = 0.01, Variance = 0.01
# Sample 76: X_n = 8.25, A_Hat = 9.89, Gain = 0.01, Variance = 0.01
# Sample 77: X_n = 12.37, A_Hat = 9.92, Gain = 0.01, Variance = 0.01
# Sample 78: X_n = 9.82, A_Hat = 9.92, Gain = 0.01, Variance = 0.01
# Sample 79: X_n = 10.03, A_Hat = 9.92, Gain = 0.01, Variance = 0.01
# Sample 80: X_n = 12.37, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 81: X_n = 10.75, A_Hat = 9.96, Gain = 0.01, Variance = 0.01
# Sample 82: X_n = 10.00, A_Hat = 9.96, Gain = 0.01, Variance = 0.01
# Sample 83: X_n = 9.03, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 84: X_n = 9.40, A_Hat = 9.94, Gain = 0.01, Variance = 0.01
# Sample 85: X_n = 9.20, A_Hat = 9.93, Gain = 0.01, Variance = 0.01
# Sample 86: X_n = 11.44, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 87: X_n = 9.89, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 88: X_n = 10.02, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 89: X_n = 9.50, A_Hat = 9.95, Gain = 0.01, Variance = 0.01
# Sample 90: X_n = 7.92, A_Hat = 9.92, Gain = 0.01, Variance = 0.01
# Sample 91: X_n = 9.56, A_Hat = 9.92, Gain = 0.01, Variance = 0.01
# Sample 92: X_n = 10.38, A_Hat = 9.93, Gain = 0.01, Variance = 0.01
# Sample 93: X_n = 11.32, A_Hat = 9.94, Gain = 0.01, Variance = 0.01
# Sample 94: X_n = 9.76, A_Hat = 9.94, Gain = 0.01, Variance = 0.01
# Sample 95: X_n = 10.28, A_Hat = 9.94, Gain = 0.01, Variance = 0.01
# Sample 96: X_n = 11.41, A_Hat = 9.96, Gain = 0.01, Variance = 0.01
# Sample 97: X_n = 10.46, A_Hat = 9.96, Gain = 0.01, Variance = 0.01
# Sample 98: X_n = 10.68, A_Hat = 9.97, Gain = 0.01, Variance = 0.01
# Sample 99: X_n = 10.76, A_Hat = 9.98, Gain = 0.01, Variance = 0.01
# Sample 100: X_n = 10.02, A_Hat = 9.98, Gain = 0.01, Variance = 0.01
